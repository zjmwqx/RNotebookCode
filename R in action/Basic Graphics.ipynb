# %%
dose <- c(20, 30, 40, 45, 60)
drugA <- c(16, 20, 27, 40, 60)
drugB <- c(15, 18, 25, 31, 40)

# %% [markdown]
# # Basic type and color setting

# %%
# opar <- par(no.readonly=TRUE)
# par(lty = 2, pch = 17)
# plot(dose, drugA, type="b")
# par(opar)

#pch cex lty lwd
#col col.axis col.lab col.main col.sub fg bg
#cex ...................
#font ..................... ps family
#col=1 col="white" col="#FFFFFF" col=rgb(1,1,1) col=hsv(0,0,1)
#colors()
#http://research.stowers-institute.org/efg/R/Color/Chart/

#continous color: rainbow(), heat.colors(), terrain.colors(), topo.colors(), cm.colors()
# n<-10
# mycolors <- rainbow(n)
# pie(rep(1,n), labels=mycolors, col=mycolors)
# mygrays <- gray(0:n/n)
# pie(rep(1,n), labels=mygrays, col=mygrays)

#names(pdfFonts())
# pdf(file="", family="sans")

#set graphic size
#par(pin=c(4,3), mai=c(1,.5,1,.2))

#main sub xlim xlab ylim ylab
#ann=FALSE  #remove default titles

# %%
# opar <-par(no.readonly=TRUE)
# par(pin=c(2,3))
# par(lwd=2, cex=1.5)
# par(cex.axis=1, font.axis=3)
# plot(dose, drugA, type="b", pch=19, lty=2, col="red")
# plot(dose, drugB, type="b", pch=23, lty=6, col="blue", bg="green")
# title(main="", sub="", xlab="", ylab="",col.lab="", cex.lab="")
# par(opar)

# %%
opar <-par(no.readonly=TRUE)
par(lwd=2, cex=1.5, font.lab=2)
plot(dose, drugA, type="b", pch=15, lty=1, col="red", ylim=c(0,60), main="Drug A vs Drug B", xlab="Drug Dosage", ylab="Drug Response")
lines(dose, drugB, type="b", pch=17, lty=2,col="blue")
abline(h=c(30), lwd=1.5, lty=2,col="gray")

library(Hmisc)
minor.tick(nx=3,ny=3, tick.ratio=0.5)
legend("topleft",inset=.05,title="Drug Type", legend=c("A", "B"), lty=c(1,2),pch=c(15,17),col=c("red", "blue"))
par(opar)
# Out:
# Plot with title “Drug A vs Drug B”

# %%
opar <- par(no.readonly=TRUE)
par(cex=1.5)
with(mtcars, {
    plot(wt, mpg, main="Mileage vs. Car Weight", xlab="Weight", ylab="Mileage",
        pch=18, col="blue")
    text(wt, mpg, row.names(mtcars), cex=0.4, pos=4, col="red")
})
par(opar)
# Out:
# Plot with title “Mileage vs. Car Weight”

# %%
opar <- par(no.readonly=TRUE)
par(cex=1.5)
plot(1:7,1:7, type="n")
text(3,3,"Example of default text")
text(4,4, family="mono", "Example of mono-spaced text")
text(5,5, family="serif", "Example of serif text")
par(opar)
# Out:
# plot without title

# %%
# demo(plotmath)

# %%
# with(mtcars, {
#     opar <- par(no.readonly=TRUE)
#     par(mfrow=c(2,2))
#     plot(wt, mpg, main="Scatterplot of wt vs. mpg")
#     plot(wt, disp, main="Scatterplot of wt vs disp")
#     hist(wt, main= "Histogram of wt", xlim=c(0,6), ylim=c(0,10))
#     boxplot(wt, main="Boxplot of wt")
#     par(opar)
# })

# %%
# with(mtcars,{
#     layout(matrix(c(1,1,2,3), 2, 2, byrow=TRUE))
#     hist(wt)
#     hist(mpg)
#     hist(disp)
# })

# %%
opar <- par(no.readonly=TRUE)
par(fig=c(0, 0.8,0,0.8))
plot(mtcars$wt, mtcars$mpg, xlab="Miles Per Gallen",ylab="Car weight")
par(fig=c(0, 0.8, 0.55, 1), new=TRUE)
boxplot(mtcars$wt, horizontal=TRUE, axes=FALSE)
par(fig=c(0.6,1,0,0.8), new=TRUE)
boxplot(mtcars$mpg, axes=FALSE)
title("Enhanced Scatterplot", cex=1.5, outer=TRUE,line=-3)
par(opar)
# Out:
# Plot with title “Enhanced Scatterplot”

# %%
names(mtcars)
# Out:
#  [1] "mpg"  "cyl"  "disp" "hp"   "drat" "wt"   "qsec" "vs"   "am"   "gear"
# [11] "carb"

# %%
# library("reshape")
# rename(mtcars,c(mpg="mmm") )

# %%
x <- c(1,2,NA,3)
y <- sum(x,na.rm=TRUE)

# %%
format(Sys.Date(), format="%A")
date()
# Out:
# [1] "Tuesday"
# [1] "Tue Nov 17 17:19:40 2015"

# %%
difftime(as.Date("1985-07-24"), Sys.Date(), unit="week")
# Out:
# Time difference of -1581.857 weeks

# %%
as.character(Sys.Date())
# Out:
# [1] "2015-11-17"

# %%
# mtcars[order(mtcars$mpg),]

# %%
# merge(mtcars, mtcars, by="mpg")

# %%
# paste("q",1:5, sep ="") ; paste("q", 1:5, collapse = "")

# %%
# 1 %in% c(1,2)

# %%
mtcars[which((mtcars$mpg > 20) & (mtcars$hp > 100)),] #should call which
# Out:
#                 mpg cyl  disp  hp drat    wt  qsec vs am gear carb
# Mazda RX4      21.0   6 160.0 110 3.90 2.620 16.46  0  1    4    4
# Mazda RX4 Wag  21.0   6 160.0 110 3.90 2.875 17.02  0  1    4    4
# Hornet 4 Drive 21.4   6 258.0 110 3.08 3.215 19.44  1  0    3    1
# Lotus Europa   30.4   4  95.1 113 3.77 1.513 16.90  1  1    5    2
# Volvo 142E     21.4   4 121.0 109 4.11 2.780 18.60  1  1    4    2

# %%
# subset(mtcars, mpg > 20 & hp > 100, select=wt:vs)
