# %%
mad(c(1,2,3,4))
# Out:
# [1] 1.4826

# %%
x <- pretty(c(1, 10), 10)

# %%
y <- dnorm(x)

# %%
pnorm(1.96)
# Out:
# [1] 0.9750021

# %%
qnorm(.9, mean=500, sd=100)
# Out:
# [1] 628.1552

# %%
opar <- par(no.readonly=TRUE)
par(mfrow=c(2,2))
plot(x, dnorm(x),type="l", yaxs="i",lty=1,col="blue")
plot(x, dpois(x,3),type="l",lty=2,col="red")
plot(x, dexp(x),type="l", lty=3,col="orange" )
legend(cex=0.5,"topleft",inset=.05, legend=c("norm", "cauchy", "exp"),lty=c(1,2,3),col=c("blue","red","orange"))
par(opar)
# Out:
# plot without title
